# %%
import os
os.chdir(r"C:\Users\eduar\Projects\Python\quant_project")

# %%
print(os.getcwd())
# Out:
# C:\Users\eduar\Projects\Python\quant_project

# %%
from data.engine import build_db
from data.repositories.price_repo import get_price_history

# %%
engine, SessionFactory = build_db()

# %%
session = SessionFactory()

# %%
df = get_price_history(
    session=session,
    assets=["MSFT"]
)

print(df.head())
# Out:
# symbol         MSFT
# price_date
# 2000-03-29  32.7381
# 2000-03-30  31.5736
# 2000-03-31  32.4517
# 2000-04-03  27.7558
# 2000-04-04  27.0495
